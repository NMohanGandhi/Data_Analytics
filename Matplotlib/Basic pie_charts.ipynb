# %%
import numpy as np

# %%
import pandas as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
# importing pandas library
import pandas as pd
# importing matplotlib library
import matplotlib.pyplot as plt
  
# creating dataframe
df = pd.DataFrame({
    'Object': ['Bulb', 'Lamp', 'Table', 'Pen', 'Notebook'],
    'Price': [45, 38, 90, 60, 40]
})
  
# plotting a pie chart
plt.pie(df["Price"], labels=df["Object"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df =pd. DataFrame({"Names":["Mohan","Teja","Ashok","NMS","MYS"],
               "Age":[22,24,23,22,20]})
plt.pie(df["Age"],labels=df["Names"])
plt.show()

# %%
df
# Out:
#    Names  Age
# 0  Mohan   22
# 1   Teja   24
# 2  Ashok   23
# 3    NMS   22
# 4    MYS   20

# %%
df["Names"]
# Out:
# 0    Mohan
# 1     Teja
# 2    Ashok
# 3      NMS
# 4      MYS
# Name: Names, dtype: object

# %%
df["Age"]
# Out:
# 0    22
# 1    24
# 2    23
# 3    22
# 4    20
# Name: Age, dtype: int64

# %%
import numpy as np

# %%
newInd = np.arange(1,len(df)+1)

# %%
df.set_index(newInd)
# Out:
#    Names  Age
# 1  Mohan   22
# 2   Teja   24
# 3  Ashok   23
# 4    NMS   22
# 5    MYS   20

# %%
df
# Out:
#    Names  Age
# 0  Mohan   22
# 1   Teja   24
# 2  Ashok   23
# 3    NMS   22
# 4    MYS   20

# %%
df.set_index(newInd,inplace=True)

# %%
df
# Out:
#    Names  Age
# 1  Mohan   22
# 2   Teja   24
# 3  Ashok   23
# 4    NMS   22
# 5    MYS   20

# %%
df
# Out:
#    Names  Age
# 1  Mohan   22
# 2   Teja   24
# 3  Ashok   23
# 4    NMS   22
# 5    MYS   20
